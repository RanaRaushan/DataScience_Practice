# %% [markdown]
# # Pandas
# ## Data Input and Output
# * CSV
# * Excel
# * HTML
# * SQL

# %%
import pandas as pd

# %%
pwd
# Out:
# 'C:\\learning\\myLearning\\GithubRepository\\myLearning\\Data Science\\Python for Data Science and Machine Learning Bootcamp\\Pandas'

# %%
pd.read_csv('example')
# Out:
#     a   b   c   d
# 0   0   1   2   3
# 1   4   5   6   7
# 2   8   9  10  11
# 3  12  13  14  15

# %%
df = pd.read_csv('example')

# %%
df.to_csv('My_output')

# %%
# if index is not False
pd.read_csv('My_output')
# Out:
#    Unnamed: 0   a   b   c   d
# 0           0   0   1   2   3
# 1           1   4   5   6   7
# 2           2   8   9  10  11
# 3           3  12  13  14  15

# %%
df.to_csv('My_output', index=False)
pd.read_csv('My_output')
# Out:
#     a   b   c   d
# 0   0   1   2   3
# 1   4   5   6   7
# 2   8   9  10  11
# 3  12  13  14  15

# %%
pd.read_excel('Excel_Sample.xlsx', sheet_name='Sheet1')
# Out:
#    Unnamed: 0   a   b   c   d
# 0           0   0   1   2   3
# 1           1   4   5   6   7
# 2           2   8   9  10  11
# 3           3  12  13  14  15

# %%
df.to_excel('Excel_Sample.xlsx',sheet_name='NewSheet', index=False)

# %%
pd.read_excel('Excel_Sample.xlsx', sheet_name='NewSheet')
# Out:
#     a   b   c   d
# 0   0   1   2   3
# 1   4   5   6   7
# 2   8   9  10  11
# 3  12  13  14  15

# %%
data = pd.read_html('https://www.fdic.gov/bank/individual/part335/')

# %%
data[0]
# Out:
#     Cert Number                        Bank Name           City          State
# 0           110                         Bank OZK    Little Rock       Arkansas
# 1         59017              First Republic Bank  San Francisco     California
# 2         33806                        Opus Bank         Irvine     California
# 3         33539                   Preferred Bank    Los Angeles     California
# 4         32203                Summit State Bank     Santa Rosa     California
# 5          4240                   Northeast Bank       Lewiston          Maine
# 6         19101                     Harford Bank       Aberdeen       Maryland
# 7         90211  Hingham Institution For Savings        Hingham  Massachusetts
# 8         11813                BancorpSouth Bank         Tupelo    Mississippi
# 9         58481                       First Bank       Hamilton     New Jersey
# 10        58513            The Bank of Princeton      Princeton     New Jersey
# 11          622                 Amalgamated Bank       New York       New York
# 12        57053                   Signature Bank       New York       New York
# 13        58596              Carter Bank & Trust  Martinsvillle       Virginia
# 14        35095                        Townebank     Portsmouth       Virginia

# %%
data = pd.read_html('https://www.fdic.gov/resources/resolutions/bank-failures/failed-bank-list/')

# %%
data[0]
# Out:
#                          Bank NameBank           CityCity StateSt  CertCert  \
# 0                    Almena State Bank             Almena      KS     15426
# 1           First City Bank of Florida  Fort Walton Beach      FL     16748
# 2                 The First State Bank      Barboursville      WV     14361
# 3                   Ericson State Bank            Ericson      NE     18265
# 4     City National Bank of New Jersey             Newark      NJ     21111
# ..                                 ...                ...     ...       ...
# 558                 Superior Bank, FSB           Hinsdale      IL     32646
# 559                Malta National Bank              Malta      OH      6629
# 560    First Alliance Bank & Trust Co.         Manchester      NH     34264
# 561  National State Bank of Metropolis         Metropolis      IL      3815
# 562                   Bank of Honolulu           Honolulu      HI     21029
#
#                  Acquiring InstitutionAI Closing DateClosing  FundFund
# 0                            Equity Bank    October 23, 2020     10538
# 1              United Fidelity Bank, fsb    October 16, 2020     10537
# 2                         MVB Bank, Inc.       April 3, 2020     10536
# 3             Farmers and Merchants Bank   February 14, 2020     10535
# 4                        Industrial Bank    November 1, 2019     10534
# ..                                   ...                 ...       ...
# 558                Superior Federal, FSB       July 27, 2001      6004
# 559                    North Valley Bank         May 3, 2001      4648
# 560  Southern New Hampshire Bank & Trust    February 2, 2001      4647
# 561              Banterra Bank of Marion   December 14, 2000      4646
# 562                   Bank of the Orient    October 13, 2000      4645
#
# [563 rows x 7 columns]

# %%
crypto_list = pd.read_html('https://coinmarketcap.com/all/views/all/')

# %%
crypto_list[2].head()
# Out:
#    Rank             Name Symbol                Market Cap       Price  \
# 0   1.0       BTCBitcoin    BTC  $653.20B$653,197,695,640  $34,848.75
# 1   2.0      ETHEthereum    ETH  $239.75B$239,748,615,723   $2,058.43
# 2   3.0       USDTTether   USDT    $62.56B$62,561,226,629       $1.00
# 3   4.0  BNBBinance Coin    BNB    $45.02B$45,022,376,821     $293.43
# 4   5.0       ADACardano    ADA    $42.81B$42,814,764,483       $1.34
#
#       Circulating Supply      Volume(24h)    % 1h   % 24h    % 7d  ...  \
# 0         18,743,793 BTC  $34,442,115,335  -0.16%   5.28%   7.81%  ...
# 1        116,471,411 ETH  $21,272,257,597  -0.25%  11.35%   5.05%  ...
# 2  62,534,142,511 USDT *  $53,413,327,556   0.01%  -0.14%  -0.07%  ...
# 3      153,432,897 BNB *   $1,531,970,704  -0.42%   4.61%  -6.03%  ...
# 4     31,946,328,269 ADA   $2,336,679,674  -0.20%   4.98%   1.88%  ...
#
#    Unnamed: 991  Unnamed: 992  Unnamed: 993  Unnamed: 994  Unnamed: 995  \
# 0           NaN           NaN           NaN           NaN           NaN
# 1           NaN           NaN           NaN           NaN           NaN
# 2           NaN           NaN           NaN           NaN           NaN
# 3           NaN           NaN           NaN           NaN           NaN
# 4           NaN           NaN           NaN           NaN           NaN
#
#    Unnamed: 996  Unnamed: 997  Unnamed: 998  Unnamed: 999  Unnamed: 1000
# 0           NaN           NaN           NaN           NaN            NaN
# 1           NaN           NaN           NaN           NaN            NaN
# 2           NaN           NaN           NaN           NaN            NaN
# 3           NaN           NaN           NaN           NaN            NaN
# 4           NaN           NaN           NaN           NaN            NaN
#
# [5 rows x 1001 columns]

# %%
from sqlalchemy import create_engine

# %%
engine = create_engine("sqlite:///:memory:")

# %%
df.to_sql('my_table',engine)

# %%
pd.read_sql('my_table',engine)
# Out:
#    index   a   b   c   d
# 0      0   0   1   2   3
# 1      1   4   5   6   7
# 2      2   8   9  10  11
# 3      3  12  13  14  15
